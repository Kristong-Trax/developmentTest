# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx

# %%
g = nx.DiGraph()

# %%
g.add_path([0,1,2,0,2,3,0])
print g.edges()
print g.nodes()

nx.draw_networkx(g)
# Out:
# [(0, 1), (0, 2), (1, 2), (2, 0), (2, 3), (3, 0)]
# [0, 1, 2, 3]
